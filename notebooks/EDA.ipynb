# %% [markdown]
# ## Exploratory Data Analysis Using London Airbnb Data

# %% [markdown]
# This notebook explores the London Airbnb dataset from Inside Airbnb.

# %% [markdown]
# 1. Imports and Setup
#     - Importing necessary libraries
#     - Loading dataset
#     - Quick data insights (shape, info)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
listings_df = pd.read_csv("../data/listings.csv")
listings_df
# Out:
#                         id                                       listing_url  \
# 0                    13913                https://www.airbnb.com/rooms/13913
# 1                    15400                https://www.airbnb.com/rooms/15400
# 2                    17402                https://www.airbnb.com/rooms/17402
# 3                    24328                https://www.airbnb.com/rooms/24328
# 4                    36274                https://www.airbnb.com/rooms/36274
# ...                    ...                                               ...
# 96866  1508894090797273412  https://www.airbnb.com/rooms/1508894090797273412
# 96867  1508900042872179492  https://www.airbnb.com/rooms/1508900042872179492
# 96868  1508926597927944565  https://www.airbnb.com/rooms/1508926597927944565
# 96869  1508962439633147670  https://www.airbnb.com/rooms/1508962439633147670
# 96870  1508964418056953740  https://www.airbnb.com/rooms/1508964418056953740
#
# ...

# %%
#Output of the first 5 rows of dataset
listings_df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  13913  https://www.airbnb.com/rooms/13913  20250914034649   2025-09-16
# 1  15400  https://www.airbnb.com/rooms/15400  20250914034649   2025-09-16
# 2  17402  https://www.airbnb.com/rooms/17402  20250914034649   2025-09-16
# 3  24328  https://www.airbnb.com/rooms/24328  20250914034649   2025-09-18
# 4  36274  https://www.airbnb.com/rooms/36274  20250914034649   2025-09-15
#
#             source                                               name  \
# 0      city scrape                Holiday London DB Room Let-on going
# 1      city scrape                Bright Chelsea  Apartment. Chelsea!
# 2      city scrape   Very Central Modern 3-Bed/2 Bath By Oxford St W1
# 3  previous scrape                   Battersea live/work artist house
# 4      city scrape  Bright 1 bedroom apt off brick lane in Shoreditch
#
#                                          description  \
# ...

# %%
#Output last 5 rows of dataset
listings_df.tail()
# Out:
#                         id                                       listing_url  \
# 96866  1508894090797273412  https://www.airbnb.com/rooms/1508894090797273412
# 96867  1508900042872179492  https://www.airbnb.com/rooms/1508900042872179492
# 96868  1508926597927944565  https://www.airbnb.com/rooms/1508926597927944565
# 96869  1508962439633147670  https://www.airbnb.com/rooms/1508962439633147670
# 96870  1508964418056953740  https://www.airbnb.com/rooms/1508964418056953740
#
#             scrape_id last_scraped       source  \
# 96866  20250914034649   2025-09-16  city scrape
# 96867  20250914034649   2025-09-15  city scrape
# 96868  20250914034649   2025-09-14  city scrape
# 96869  20250914034649   2025-09-15  city scrape
# 96870  20250914034649   2025-09-15  city scrape
#
#                                                     name  \
# 96866      Blueground | Finsbury, balcony, nr St. Paul's
# 96867  Self-Contained Studio in Heart of Tooting Broa...
# ...

# %%
#Columns and rows of dataset
listings_df.shape
# Out:
# (96871, 79)

# %%
#Summary Statistics of dataset
listings_df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  9.687100e+04  9.687100e+04  9.687100e+04         96830.000000
# mean   6.894448e+17  2.025091e+13  2.144494e+08            50.088991
# std    5.941222e+17  0.000000e+00  2.196053e+08           399.405694
# min    1.391300e+04  2.025091e+13  2.594000e+03             1.000000
# 25%    3.026058e+07  2.025091e+13  2.726814e+07             1.000000
# 50%    8.505248e+17  2.025091e+13  1.164321e+08             2.000000
# 75%    1.254262e+18  2.025091e+13  4.198974e+08            10.000000
# max    1.508964e+18  2.025091e+13  7.186905e+08          5469.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               96830.000000                           0.0  96871.000000
# mean                   80.305246                           NaN     51.509740
# std                   589.326173                           NaN      0.049067
# ...
